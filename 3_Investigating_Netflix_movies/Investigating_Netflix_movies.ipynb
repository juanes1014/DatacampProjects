# %% [markdown]
# ![Movie popcorn on red background](redpopcorn.jpg)

# %% [markdown]
# **Netflix**! What started in 1997 as a DVD rental service has since exploded into one of the largest entertainment and media companies.
#
# Given the large number of movies and series available on the platform, it is a perfect opportunity to flex your exploratory data analysis skills and dive into the entertainment industry. Our friend has also been brushing up on their Python skills and has taken a first crack at a CSV file containing Netflix data. They believe that the average duration of movies has been declining. Using your friends initial research, you'll delve into the Netflix data to see if you can determine whether movie lengths are actually getting shorter and explain some of the contributing factors, if any.
#
# You have been supplied with the dataset `netflix_data.csv` , along with the following table detailing the column names and descriptions. This data does contain null values and some outliers, but handling these is out of scope for the project. Feel free to experiment after submitting!
#
# ## The data
# ### **netflix_data.csv**
# | Column | Description |
# |--------|-------------|
# | `show_id` | The ID of the show |
# | `type` | Type of show |
# | `title` | Title of the show |
# | `director` | Director of the show |
# | `cast` | Cast of the show |
# | `country` | Country of origin |
# | `date_added` | Date added to Netflix |
# | `release_year` | Year of Netflix release |
# | `duration` | Duration of the show in minutes |
# | `description` | Description of the show |
# | `genre` | Show genre |

# %%
# Importing pandas and matplotlib
import pandas as pd
import matplotlib.pyplot as plt

# Start coding!
# Cargamos el archivo .csv con la función pd.read_csv('data')
netflix_df=pd.read_csv('C:\\Users\\ASUS\\Desktop\\Data_Science\\DataCamp\\Associate_data_scientist_in_Python\\Projects\\3_Investigating_Netflix_movies\\netflix_data.csv',index_col=0)
netflix_df
# Out:
#             type                                    title           director  \
# show_id
# s1       TV Show                                       3%                NaN
# s2         Movie                                     7:19  Jorge Michel Grau
# s3         Movie                                    23:59       Gilbert Chan
# s4         Movie                                        9        Shane Acker
# s5         Movie                                       21     Robert Luketic
# ...          ...                                      ...                ...
# s7783      Movie                                     Zozo        Josef Fares
# s7784      Movie                                   Zubaan        Mozez Singh
# s7785      Movie                        Zulu Man in Japan                NaN
# s7786    TV Show                    Zumbo's Just Desserts                NaN
# s7787      Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
# ...

# %%
#Filtramos los tv shows de la columna type.
tv_shows=netflix_df['type']!='TV Show'
netflix_subset=netflix_df[tv_shows]
netflix_subset
# Out:
#           type                                    title           director  \
# show_id
# s2       Movie                                     7:19  Jorge Michel Grau
# s3       Movie                                    23:59       Gilbert Chan
# s4       Movie                                        9        Shane Acker
# s5       Movie                                       21     Robert Luketic
# s7       Movie                                      122    Yasir Al Yasiri
# ...        ...                                      ...                ...
# s7782    Movie                                     Zoom       Peter Hewitt
# s7783    Movie                                     Zozo        Josef Fares
# s7784    Movie                                   Zubaan        Mozez Singh
# s7785    Movie                        Zulu Man in Japan                NaN
# s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS           Sam Dunn
#
# ...

# %%
#Creamos un nuevo DataFrame en el cual mantendremos las siguientes columnas "title", "country", "genre", "release_year" y "duration".
netflix_movies=netflix_subset.loc[:,['title','country','genre','release_year','duration']]
netflix_movies
# Out:
#                                            title         country  \
# show_id
# s2                                          7:19          Mexico
# s3                                         23:59       Singapore
# s4                                             9   United States
# s5                                            21   United States
# s7                                           122           Egypt
# ...                                          ...             ...
# s7782                                       Zoom   United States
# s7783                                       Zozo          Sweden
# s7784                                     Zubaan           India
# s7785                          Zulu Man in Japan             NaN
# s7787    ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS  United Kingdom
#
#                  genre  release_year  duration
# show_id
# s2              Dramas          2016        93
# s3       Horror Movies          2011        78
# ...

# %%
#Filtrar las películas con una duración menor a 60 minutos.
short=netflix_movies['duration']<60
short_movies=netflix_movies[short]
short_movies
# Out:
#                                                      title        country  \
# show_id
# s36                                              #Rucker50  United States
# s56                    100 Things to do Before High School  United States
# s68      13TH: A Conversation with Oprah Winfrey & Ava ...            NaN
# s102                                     3 Seconds Divorce         Canada
# s147                                        A 3 Minute Hug         Mexico
# ...                                                    ...            ...
# s7680                      WWII: Report from the Aleutians  United States
# s7693    Ya no estoy aquí: Una conversación entre Guill...            NaN
# s7719                       Yoo Byung Jae: Discomfort Zone    South Korea
# s7772                                                 Zion  United States
# s7785                                    Zulu Man in Japan            NaN
#
#                  genre  release_year  duration
# show_id
# ...

# %%
#Crear una lista y asignando un color a cada género, para luego agregarlo a la lista.
colors=[]
for lab,row in netflix_movies.iterrows():
    if row['genre']=='Children':
        colors.append('Green')
    elif row['genre']=='Documentaries':
        colors.append('Orange')
    elif row['genre']=='Stand-Up':
        colors.append('Red')
    else:
        colors.append('Blue')

# %%
#Graficar el año de salida vs duración.
plt.clf()
fig,axs= plt.subplots(1, figsize=(12, 8))
plt.scatter(netflix_movies['release_year'],netflix_movies['duration'], s=10, c=colors, alpha=0.6)
plt.xlabel('Release year')
plt.ylabel('Duration (min)')
plt.title('Movie Duration by Year of Release')
plt.show()

# %%
answer='no'
